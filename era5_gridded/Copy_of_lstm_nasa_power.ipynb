# %% [markdown]
# # LSTM temporel (TensorFlow/Keras) — prévision Heat Index & Wind Chill (NASA POWER, stations Maroc)
#
# Approche **séries temporelles par station** en **TensorFlow/Keras** (inspirée de
# `lstm_heat_index_prediction.ipynb`). On entraîne et compare cinq modèles
# temporels — **LSTM**, **GRU**, **TCN**, **BiLSTM**, **TFT** — sur les stations NASA POWER : à partir
# des `INPUT_WINDOW` derniers jours de variables météo, on prédit les
# `OUTPUT_WINDOW` prochains jours de **HeatIndex** et **WindChill**.
#
# Pipeline : chargement → nettoyage → features → heatmap de corrélation →
# **split chronologique par station 70/15/15** → **normalisation Min-Max (fit train only)**
# → fenêtrage (par station) → modèles Keras → entraînement (`model.fit` + callbacks)
# → évaluation (RMSE/MAE/R²) → comparaison → visualisation → sauvegarde
# (`.keras` + scalers).

# %% [markdown]
# ## 0. Imports & configuration

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip -q install pyarrow

import os, glob, json, math, gc, time
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import joblib
import pyarrow.parquet as pqx
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
import warnings; warnings.filterwarnings("ignore")

SEED = 42
np.random.seed(SEED); tf.random.set_seed(SEED)
print("TensorFlow:", tf.__version__)
print("GPU:", tf.config.list_physical_devices("GPU"))

# %%
# ── Configuration centrale du benchmark (source de vérité unique) ──
from dataclasses import dataclass, field, asdict
from typing import List
import os
from pathlib import Path
import numpy as np
import tensorflow as tf
import json

@dataclass
class Config:
    """Tous les hyperparamètres, chemins, features et cibles du benchmark LSTM
    temporel (ERA5-Land, tout le Maroc). Modifier ICI propage a tout le notebook."""
    # — Données / chemins —
    data_dir: str = "/content/drive/MyDrive/ERA5_land_LSTM_parquet"  # dossier des parquet ERA5 (déjà convertis)
    art_dir:  str = "/content/drive/MyDrive/lstm_era5_land_morocco/"  # sorties (modèles, scalers, métriques)
    # — Features & cibles (sélectionnées PAR NOM, pas par slicing) —
    features: List[str] = field(default_factory=lambda: [
        "latitude", "longitude", "elevation",
        "tmax_c", "tmin_c", "dewp_c", "humidity_pct",
        "wind_speed_ms", "press_hpa", "heat_index", "wind_chill"
        ])
    targets:  List[str] = field(default_factory=lambda: ["heat_index", "wind_chill"])
    # — Fenêtrage temporel —
    input_window:  int = 7        # jours passés fournis au modèle
    output_window: int = 7        # jours prédits
    # — Split chronologique par station (70 / 15 / 15) —
    train_ratio: float = 0.70
    val_ratio:   float = 0.15
    test_ratio:  float = 0.15
    # — Modèle —
    # hidden:   int = 32
    # n_layers: int = 2
    # dropout:  float = 0.3
    # # — Entraînement —
    # batch_size: int = 16
    # epochs:     int = 100
    # lr:         float = 1e-4
    # patience:   int = 16
    # seed:       int = 42

    hidden:   int = 32          # <-- Reduced capacity to prevent early memorization
    n_layers: int = 2           # <-- Keep stacked layers
    dropout:  float = 0.3       # <-- Higher dropout for stronger regularization
    # — Entraînement —
    batch_size: int = 128       # <-- Larger batch size for smoother gradients
    epochs:     int = 100
    lr:         float = 1e-4    # <-- Slower learning rate to delay overfitting
    patience:   int = 20        # <-- More patience for slower learning
    seed:       int = 42

    @property
    def n_features(self) -> int: return len(self.features)
    @property
    def n_targets(self) -> int:  return len(self.targets)

cfg = Config()
assert abs(cfg.train_ratio + cfg.val_ratio + cfg.test_ratio - 1.0) < 1e-9, "les ratios doivent sommer à 1"

# Reproductibilité pilotée par la config
np.random.seed(cfg.seed); tf.random.set_seed(cfg.seed)

# ── Alias module-level (utilisés dans tout le notebook) ──
DATA_DIR = cfg.data_dir
ART_DIR  = Path(cfg.art_dir); ART_DIR.mkdir(parents=True, exist_ok=True)
FEATURES = list(cfg.features)
TARGETS  = list(cfg.targets)
INPUT_WINDOW, OUTPUT_WINDOW = cfg.input_window, cfg.output_window
TRAIN_RATIO, VAL_RATIO, TEST_RATIO = cfg.train_ratio, cfg.val_ratio, cfg.test_ratio
HIDDEN, N_LAYERS, DROPOUT = cfg.hidden, cfg.n_layers, cfg.dropout
BATCH_SIZE, EPOCHS, LR, PATIENCE = cfg.batch_size, cfg.epochs, cfg.lr, cfg.patience

# ── Contrôles RAM (Colab gratuit ≈ 12.7 Go) ──────────────────────────────────
#   On lit les parquet déjà convertis et on échantillonne un sous-ensemble de
#   pixels (stations) réparti uniformément — mêmes pixels sur toutes les années.
MAX_PIXELS = 300     # nb max de pixels/stations ; None = tous (⚠️ RAM)
YEARS      = None    # ex: list(range(2010,2026)) filtre par nom de fichier ; None = tous
MAX_FILES  = None    # ex: 3 pour un test rapide ; None = tous
print(f"RAM ctrl -> max_pixels={MAX_PIXELS}, years={YEARS}, max_files={MAX_FILES}")

print("Config centrale:\n" + json.dumps(asdict(cfg), indent=2, ensure_ascii=False))
print("DATA_DIR:", DATA_DIR)
print("ART_DIR:", ART_DIR)

# %% [markdown]
# ## 1. Load all stations

# %% [markdown]
# Les données proviennent des **parquet ERA5-Land déjà convertis** (`DATA_DIR = ERA5_land_LSTM_parquet`). Chaque **pixel de grille** est une *station*. Pour tenir dans la RAM de Colab on **échantillonne** `MAX_PIXELS` pixels (répartis uniformément, identiques sur toutes les années) et on lit les parquet en **élaguant colonnes + pixels**.

# %%
# ── Chargement direct des parquet ERA5 (déjà convertis) ──
pq_files = sorted(glob.glob(os.path.join(DATA_DIR, "**", "*.parquet"), recursive=True))
assert pq_files, f"Aucun .parquet dans {DATA_DIR}"
if YEARS:
    yrs = {str(y) for y in YEARS}
    pq_files = [f for f in pq_files if any(y in os.path.basename(f) for y in yrs)]
if MAX_FILES:
    pq_files = pq_files[:MAX_FILES]
print(f"{len(pq_files)} fichier(s) parquet\n")

# Sous-ensemble de pixels (mêmes pixels sur toutes les années -> séries continues)
pix0 = np.sort(pd.read_parquet(pq_files[0], columns=["pixel_id"])["pixel_id"].unique())
if MAX_PIXELS and len(pix0) > MAX_PIXELS:
    step = max(1, len(pix0) // MAX_PIXELS)
    sel = set(pix0[::step][:MAX_PIXELS].tolist())
else:
    sel = set(pix0.tolist())
print(f"pixels retenus : {len(sel)} / {len(pix0)}")

want = ["pixel_id", "date"] + list(dict.fromkeys(FEATURES + TARGETS))
frames = []
for k, f in enumerate(pq_files, 1):
    avail = pqx.ParquetFile(f).schema.names           # lecture colonnes présentes
    cols  = [c for c in want if c in avail]
    df = pd.read_parquet(f, columns=cols)             # column pruning -> RAM
    df = df[df["pixel_id"].isin(sel)]                 # pixel pruning -> RAM
    for c in df.select_dtypes("float64").columns:
        df[c] = df[c].astype("float32")
    frames.append(df)
    print(f"[{k}/{len(pq_files)}] {os.path.basename(f)}: {len(df)} lignes")

data = pd.concat(frames, ignore_index=True); del frames; gc.collect()
# pixel_id -> "station" (compatibilité avec tout le reste du notebook)
data["station"] = data["pixel_id"].astype(str)
data = data.drop(columns=["pixel_id"])
missing = [c for c in FEATURES + TARGETS if c not in data.columns]
assert not missing, f"colonnes manquantes dans les parquet: {missing}"
print("\nstations (pixels):", data["station"].nunique(), "| rows:", len(data))
print("date range:", data["date"].min().date(), "->", data["date"].max().date())
print("RAM du DataFrame:", round(data.memory_usage(deep=True).sum()/1e6, 1), "Mo")
data.head()

# %% [markdown]
# ## 2. Clean & feature engineering
# - Drop the trailing constant-repeat rows NASA POWER pads at the end of each station.
# - Add cyclical day-of-year features for seasonality.

# %%
data = data.sort_values(["station","date"]).reset_index(drop=True)

# Remove consecutive exact-duplicate tail rows (NASA POWER pads the latest days)
def _strip_tail_dupes(g):
    key = ["tmax_c","tmin_c","humidity_pct","press_hpa"]
    dup = (g[key].diff().abs().sum(axis=1) == 0)
    tail_mask = dup & (dup[::-1].cummin()[::-1])
    return g[~tail_mask]
data = pd.concat([_strip_tail_dupes(g) for _, g in data.groupby("station")], ignore_index=True)

# Drop rows with NaN in any used column
need = FEATURES
before = len(data); data = data.dropna(subset=need).reset_index(drop=True)
print(f"dropped {before-len(data)} NaN/dupe rows -> {len(data)} rows")

# ── Redéfinir WindChill en "température ressentie" (Apparent Temperature, Steadman) ──
_e = (data["humidity_pct"] / 100.0) * 6.105 * np.exp(17.27 * data["tmin_c"] / (237.7 + data["tmin_c"]))
data["wind_chill"] = data["tmin_c"] + 0.33 * _e - 0.70 * data["wind_speed_ms"] - 4.00
print(f"wind_chill redéfini (Apparent Temp) | corr avec Tmin: "
      f"{data['wind_chill'].corr(data['tmin_c']):.3f}")

# Cyclical seasonality
# doy = data["date"].dt.dayofyear
# data["doy_sin"] = np.sin(2*np.pi*doy/365.25)
# data["doy_cos"] = np.cos(2*np.pi*doy/365.25)
# FEATURES = FEATURES + ["doy_sin","doy_cos"]
# print("n_features:", len(FEATURES), "| targets:", TARGETS)
# Out:
# dropped 22740 NaN/dupe rows -> 301329 rows
# wind_chill redéfini (Apparent Temp) | corr avec Tmin: 0.960

# %% [markdown]
# ## 2bis. Matrice de corrélation (features & cibles)
# Heatmap de Pearson (seaborn) sur le jeu complet **après** nettoyage et ajout des
# features de saisonnalité — pour repérer la redondance et les liens avec les
# cibles `HeatIndex` / `WindChill` avant l'entraînement.

# %%
# ── Heatmap de corrélation complète (features + cibles) ──
corr_cols = FEATURES
corr = data[corr_cols].corr()

plt.figure(figsize=(14, 11))
sns.heatmap(corr, annot=True, fmt=".2f", cmap="coolwarm", center=0,
            vmin=-1, vmax=1, square=True, linewidths=.5, cbar_kws={"shrink": .8})
plt.title("Matrice de corrélation — features & cibles", fontsize=14, fontweight="bold")
plt.tight_layout(); plt.show()

# Paires fortement colinéaires (|r| > 0.9, hors diagonale) -> redondance / fuite potentielle
keep = np.tril(np.ones_like(corr, dtype=bool), k=-1)
pairs = corr.where(keep).abs().stack().sort_values(ascending=False)
pairs = pairs[pairs > 0.9]
print("Paires |r| > 0.9 (redondance potentielle):")
for (a, b), _ in pairs.items():
    print(f"  {a:>14s} ~ {b:<14s} r={corr.loc[a, b]:+.3f}")

# Top corrélations (|r|) de chaque cible avec les features
for t in TARGETS:
    order = corr[t].drop(TARGETS).abs().sort_values(ascending=False).head(5).index
    print(f"\nTop |r| avec {t}:")
    print(corr.loc[order, t].round(3).to_string())
# Out:
# Paires |r| > 0.9 (redondance potentielle):
#       heat_index ~ tmax_c         r=+0.989
#       wind_chill ~ tmin_c         r=+0.960
#        longitude ~ latitude       r=+0.918
#
# Top |r| avec heat_index:
# tmax_c          0.989
# tmin_c          0.742
# humidity_pct   -0.460
# dewp_c          0.396
# latitude       -0.068
#
# Top |r| avec wind_chill:
# tmin_c       0.960
# dewp_c       0.735
# tmax_c       0.627
# elevation   -0.285
# longitude   -0.174

# %% [markdown]
# ## 3. Split chronologique par station — 70 / 15 / 15
# On découpe **chaque station** dans l'ordre temporel : 70 % d'abord (train),
# puis 15 % (val), puis 15 % (test). Ce choix de senior évite la fuite de données
# — pas de mélange aléatoire, pas de chevauchement de stations entre les jeux,
# et chaque jeu reste contigu dans le temps.

# %%
def split_station(g):
    g = g.sort_values("date")
    n = len(g)
    i_tr = int(n * TRAIN_RATIO)
    i_va = int(n * (TRAIN_RATIO + VAL_RATIO))
    return g.iloc[:i_tr], g.iloc[i_tr:i_va], g.iloc[i_va:]

parts = [split_station(g) for _, g in data.groupby("station")]
train_df = pd.concat([p[0] for p in parts], ignore_index=True)
val_df   = pd.concat([p[1] for p in parts], ignore_index=True)
test_df  = pd.concat([p[2] for p in parts], ignore_index=True)

tot = len(data)
for name, d in [("train",train_df),("val",val_df),("test",test_df)]:
    print(f"{name:5s}: {len(d):7d} rows ({len(d)/tot*100:4.1f}%)  "
          f"{d['date'].min().date()} -> {d['date'].max().date()}")
# Out:
# train:  210927 rows (70.0%)  1990-01-01 -> 2019-06-14
# val  :   45199 rows (15.0%)  2012-06-06 -> 2022-07-19
# test :   45203 rows (15.0%)  2017-03-28 -> 2025-08-24

# %% [markdown]
# ## 4. Normalisation Z-score

# %%
scaler_X = StandardScaler().fit(train_df[FEATURES])
# On n'a plus besoin de scaler_y car TARGETS est inclus dans FEATURES

def scale(df):
    df = df.copy()
    # Transforme TOUTES les features, ce qui inclut HeatIndex et WindChill
    df[FEATURES] = scaler_X.transform(df[FEATURES])
    return df

train_n, val_n, test_n = scale(train_df), scale(val_df), scale(test_df)
print("features mean (train, post-scale):", np.mean(train_n[FEATURES].to_numpy()[:1000]))

# Affichage des moyennes/écarts-types pour les cibles via scaler_X
tgt_indices = [FEATURES.index(t) for t in TARGETS]
print("targets mean_ :", dict(zip(TARGETS, np.round(scaler_X.mean_[tgt_indices], 2))))
print("targets scale_ (std) :", dict(zip(TARGETS, np.round(scaler_X.scale_[tgt_indices], 2))))
# Out:
# features mean (train, post-scale): 0.08018294014197834
# targets mean_ : {'heat_index': np.float64(23.66), 'wind_chill': np.float64(10.52)}
# targets scale_ (std) : {'heat_index': np.float64(6.49), 'wind_chill': np.float64(6.33)}

# %% [markdown]
# ## 5. Windowing — per-station sliding sequences
# Windows never cross a station boundary. X = INPUT_WINDOW days of features; y = next OUTPUT_WINDOW days of targets.

# %%
def make_sequences(df_norm):
    Xs, Ys = [], []
    win = INPUT_WINDOW + OUTPUT_WINDOW
    for _, g in df_norm.groupby("station"):
        g = g.sort_values("date")
        F = g[FEATURES].to_numpy(np.float32)
        T = g[TARGETS].to_numpy(np.float32)
        for i in range(len(g) - win + 1):
            Xs.append(F[i:i+INPUT_WINDOW])
            Ys.append(T[i+INPUT_WINDOW:i+win])
    if not Xs:
        return (np.empty((0,INPUT_WINDOW,len(FEATURES)),np.float32),
                np.empty((0,OUTPUT_WINDOW,len(TARGETS)),np.float32))
    return np.stack(Xs), np.stack(Ys)

X_tr, y_tr = make_sequences(train_n)
X_va, y_va = make_sequences(val_n)
X_te, y_te = make_sequences(test_n)
print("X_train:", X_tr.shape, "y_train:", y_tr.shape)
print("X_val  :", X_va.shape, "X_test:", X_te.shape)
# Out:
# X_train: (210615, 7, 11) y_train: (210615, 7, 2)
# X_val  : (44887, 7, 11) X_test: (44891, 7, 11)

# %% [markdown]
# ## 6. Modèles temporels Keras — LSTM · GRU · TCN · BiLSTM · TFT
# Cinq architectures partageant la même interface `(INPUT_WINDOW, n_features) -> (OUTPUT_WINDOW, n_targets)`, donc directement comparables. RNN empilés (`N_LAYERS`) ; **BiLSTM** encode la fenêtre dans les deux sens ; **TCN** = convolutions 1D causales dilatées (non-récurrent) ; **TFT** = Temporal Fusion Transformer compact (GRN + encodeur LSTM + self-attention multi-tête).

# %%
def _grn(x, units, dropout=DROPOUT):
    """Gated Residual Network (Lim et al., 2021) — brique de base du TFT.
    Projection ELU -> gating GLU -> connexion résiduelle -> LayerNorm."""
    residual = x if x.shape[-1] == units else layers.Dense(units)(x)
    h = layers.Dense(units, activation="elu")(x)
    h = layers.Dense(units)(h)
    h = layers.Dropout(dropout)(h)
    gate = layers.Dense(units, activation="sigmoid")(h)   # GLU
    h = layers.Multiply()([h, gate])
    return layers.LayerNormalization()(layers.Add()([residual, h]))


def build_model(name):
    """Construit & compile un modèle Keras à partir de la config centrale."""
    nf, nt = len(FEATURES), len(TARGETS)
    inp = keras.Input(shape=(INPUT_WINDOW, nf))

    if name in ("LSTM", "GRU"):
        RNN = layers.LSTM if name == "LSTM" else layers.GRU
        x = inp
        for li in range(N_LAYERS):
            x = RNN(HIDDEN, return_sequences=(li < N_LAYERS - 1))(x)
            x = layers.Dropout(DROPOUT)(x)
    elif name == "BiLSTM":
        x = inp
        for li in range(N_LAYERS):                 # LSTM bidirectionnel (encodeur)
            x = layers.Bidirectional(
                layers.LSTM(HIDDEN, return_sequences=(li < N_LAYERS - 1)))(x)
            x = layers.Dropout(DROPOUT)(x)
    elif name == "Stacked_LSTM":
        x = inp
        for li in range(N_LAYERS):
            x = layers.LSTM(HIDDEN, return_sequences=(li < N_LAYERS - 1))(x)
            x = layers.LayerNormalization()(x)         # <-- Added LayerNorm for stability
            x = layers.Dropout(DROPOUT)(x)
        x = layers.Dense(HIDDEN, activation="relu")(x) # <-- Added extra capacity
    elif name == "TCN":
        x = inp
        for d in (1, 2, 4):                         # convolutions causales dilatées
            x = layers.Conv1D(HIDDEN, 3, padding="causal", dilation_rate=d,
                              activation="relu")(x)
            x = layers.Dropout(DROPOUT)(x)
        x = x[:, -1, :]                             # dernier pas de temps
    elif name == "TFT":
        # Temporal Fusion Transformer (version compacte) : embedding par variable
        # via GRN -> encodeur LSTM -> self-attention multi-tête interprétable -> GRN.
        u = HIDDEN
        x = layers.Dense(u)(inp)                    # embedding des variables
        x = _grn(x, u)                              # variable selection / processing
        x = layers.LSTM(u, return_sequences=True)(x)  # traitement local séquentiel
        x = _grn(x, u)                              # enrichissement
        attn = layers.MultiHeadAttention(num_heads=4, key_dim=max(1, u // 4))(x, x)
        x = layers.LayerNormalization()(layers.Add()([x, layers.Dropout(DROPOUT)(attn)]))
        x = _grn(x, u)                              # feed-forward position-wise
        x = x[:, -1, :]                             # contexte final
    else:
        raise ValueError(f"modèle inconnu: {name}")

    x = layers.Dense(OUTPUT_WINDOW * nt)(x)
    out = layers.Reshape((OUTPUT_WINDOW, nt))(x)
    m = keras.Model(inp, out, name=name)
    m.compile(optimizer=keras.optimizers.Adam(LR), loss="mse", metrics=["mae"])
    return m

MODEL_NAMES = ["LSTM", "Stacked_LSTM", "GRU"]
for nm in MODEL_NAMES:
    print(f"{nm:12s} | params: {build_model(nm).count_params()/1e6:.3f} M")
# Out:
# LSTM         | params: 0.014 M
# Stacked_LSTM | params: 0.016 M
# GRU          | params: 0.011 M

# %% [markdown]
# ## 7. Benchmark — entraînement multi-modèles
# Boucle identique pour chaque modèle : `model.fit` avec early stopping et
# réduction du learning rate sur la validation.

# %%
CKPT_DIR   = ART_DIR / "checkpoints"; CKPT_DIR.mkdir(exist_ok=True)
MODELS_DIR = ART_DIR / "models";      MODELS_DIR.mkdir(exist_ok=True)

def train_keras(name, epochs=EPOCHS):
    m = build_model(name)
    cbs = [
        EarlyStopping(monitor="val_loss", patience=PATIENCE,
                      restore_best_weights=True, verbose=0),
        ReduceLROnPlateau(monitor="val_loss", factor=0.5,
                          patience=max(2, PATIENCE // 2), min_lr=1e-6, verbose=0),
        # Reprise après coupure : sauve l'état COMPLET (poids + optimiseur + epoch)
        # à chaque epoch et reprend automatiquement là où on s'est arrêté au redémarrage.
        keras.callbacks.BackupAndRestore(backup_dir=str(CKPT_DIR / f"backup_{name}")),
        # Meilleur checkpoint par modèle (selon val_loss)
        keras.callbacks.ModelCheckpoint(filepath=str(CKPT_DIR / f"{name}_best.keras"),
                                        monitor="val_loss", save_best_only=True, verbose=1),
        # Historique persistant (append -> survit aux coupures)
        keras.callbacks.CSVLogger(str(CKPT_DIR / f"{name}_history.csv"), append=True),
    ]
    h = m.fit(X_tr, y_tr, validation_data=(X_va, y_va), epochs=epochs,
              batch_size=BATCH_SIZE, callbacks=cbs, verbose=1)
    return m, h.history

def inv_y(arr):                                  # [N, OUT, n_targets] scaled -> physical
    N, O, T = arr.shape
    # On crée un tableau vide avec le bon nombre de features pour scaler_X
    dummy = np.zeros((N * O, len(FEATURES)))
    # On identifie les indices des targets dans les features
    tgt_indices = [FEATURES.index(t) for t in TARGETS]
    # On place nos prédictions/vrais valeurs dans les bonnes colonnes
    dummy[:, tgt_indices] = arr.reshape(-1, T)
    # On applique la transformation inverse
    inv_dummy = scaler_X.inverse_transform(dummy)
    # On ne récupère que les colonnes correspondant à nos targets
    return inv_dummy[:, tgt_indices].reshape(N, O, T)

def eval_metrics(p, t):                          # p, t in physical units
    rmse = np.sqrt(((p - t) ** 2).mean(axis=0))  # [OUT, n_targets]
    mae  = np.abs(p - t).mean(axis=0)
    r2 = np.array([r2_score(t[..., j].ravel(), p[..., j].ravel())
                   for j in range(t.shape[-1])])
    return rmse, mae, r2

true = inv_y(y_te)
results, histories = {}, {}
for name in MODEL_NAMES:
    print(f"\n===== {name} =====")
    model_path = MODELS_DIR / f"{name}.keras"

    # Si le modèle final existe déjà, on le charge pour éviter de tout recommencer
    if model_path.exists():
        print(f"[{name}] Already fully trained. Loading from {model_path}...")
        m = keras.models.load_model(str(model_path))

        hist_path = CKPT_DIR / f"{name}_history.csv"
        if hist_path.exists():
            import pandas as pd
            hist = pd.read_csv(hist_path).to_dict(orient="list")
        else:
            hist = {}
    else:
        m, hist = train_keras(name)
        m.save(str(model_path))    # on sauvegarde CHAQUE modèle entraîné une fois fini

    pred = inv_y(m.predict(X_te, verbose=0))
    rmse, mae, r2 = eval_metrics(pred, true)
    results[name] = {"model": m, "pred": pred, "rmse": rmse, "mae": mae, "r2": r2,
                     "n_params": m.count_params()}
    histories[name] = hist

# Meilleur modèle (RMSE moyen sur le test) -> exposé pour les cellules suivantes
best_name = min(results, key=lambda k: results[k]["rmse"].mean())
model, pred = results[best_name]["model"], results[best_name]["pred"]
print(f"\nMeilleur modèle (RMSE moyen test): {best_name}")
# Out:
# ===== LSTM =====
# Epoch 1/100
# 13157/13164 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.4008 - mae: 0.4806
# Epoch 1: val_loss improved from None to 0.25702, saving model to /content/drive/My Drive/lstm_testing_noaa_gsod_by_station/checkpoints/LSTM_best.keras
#
# Epoch 1: finished saving model to /content/drive/My Drive/lstm_testing_noaa_gsod_by_station/checkpoints/LSTM_best.keras
# 13164/13164 ━━━━━━━━━━━━━━━━━━━━ 133s 10ms/step - loss: 0.3209 - mae: 0.4290 - val_loss: 0.2570 - val_mae: 0.3806 - learning_rate: 1.0000e-04
# Epoch 2/100
# 13160/13164 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2747 - mae: 0.3950
# Epoch 2: val_loss improved from 0.25702 to 0.24901, saving model to /content/drive/My Drive/lstm_testing_noaa_gsod_by_station/checkpoints/LSTM_best.keras
#
# Epoch 2: finished saving model to /content/drive/My Drive/lstm_testing_noaa_gsod_by_station/checkpoints/LSTM_best.keras
# 13164/13164 ━━━━━━━━━━━━━━━━━━━━ 128s 10ms/step - loss: 0.2706 - mae: 0.3918 - val_loss: 0.2490 - val_mae: 0.3739 - learning_rate: 1.0000e-04
# Epoch 3/100
# 13164/13164 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2637 - mae: 0.3861
# Epoch 3: val_loss improved from 0.24901 to 0.24424, saving model to /content/drive/My Drive/lstm_testing_noaa_gsod_by_station/checkpoints/LSTM_best.keras
#
# Epoch 3: finished saving model to /content/drive/My Drive/lstm_testing_noaa_gsod_by_station/checkpoints/LSTM_best.keras
# 13164/13164 ━━━━━━━━━━━━━━━━━━━━ 129s 10ms/step - loss: 0.2617 - mae: 0.3845 - val_loss: 0.2442 - val_mae: 0.3699 - learning_rate: 1.0000e-04
# Epoch 4/100
# 13161/13164 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2593 - mae: 0.3825
# Epoch 4: val_loss improved from 0.24424 to 0.24241, saving model to /content/drive/My Drive/lstm_testing_noaa_gsod_by_station/checkpoints/LSTM_best.keras
#
# Epoch 4: finished saving model to /content/drive/My Drive/lstm_testing_noaa_gsod_by_station/checkpoints/LSTM_best.keras
# 13164/13164 ━━━━━━━━━━━━━━━━━━━━ 129s 10ms/step - loss: 0.2578 - mae: 0.3813 - val_loss: 0.2424 - val_mae: 0.3684 - learning_rate: 1.0000e-04
# Epoch 5/100
# 13164/13164 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2569 - mae: 0.3805
# Epoch 5: val_loss improved from 0.24241 to 0.24168, saving model to /content/drive/My Drive/lstm_testing_noaa_gsod_by_station/checkpoints/LSTM_best.keras
#
# Epoch 5: finished saving model to /content/drive/My Drive/lstm_testing_noaa_gsod_by_station/checkpoints/LSTM_best.keras
# 13164/13164 ━━━━━━━━━━━━━━━━━━━━ 129s 10ms/step - loss: 0.2556 - mae: 0.3795 - val_loss: 0.2417 - val_mae: 0.3677 - learning_rate: 1.0000e-04
# Epoch 6/100
# 13162/13164 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2556 - mae: 0.3793
# Epoch 6: val_loss improved from 0.24168 to 0.24120, saving model to /content/drive/My Drive/lstm_testing_noaa_gsod_by_station/checkpoints/LSTM_best.keras
#
# Epoch 6: finished saving model to /content/drive/My Drive/lstm_testing_noaa_gsod_by_station/checkpoints/LSTM_best.keras
# 13164/13164 ━━━━━━━━━━━━━━━━━━━━ 131s 10ms/step - loss: 0.2544 - mae: 0.3784 - val_loss: 0.2412 - val_mae: 0.3671 - learning_rate: 1.0000e-04
# Epoch 7/100
# 13164/13164 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2541 - mae: 0.3782
# Epoch 7: val_loss improved from 0.24120 to 0.24027, saving model to /content/drive/My Drive/lstm_testing_noaa_gsod_by_station/checkpoints/LSTM_best.keras
#
# Epoch 7: finished saving model to /content/drive/My Drive/lstm_testing_noaa_gsod_by_station/checkpoints/LSTM_best.keras
# 13164/13164 ━━━━━━━━━━━━━━━━━━━━ 144s 10ms/step - loss: 0.2531 - mae: 0.3773 - val_loss: 0.2403 - val_mae: 0.3669 - learning_rate: 1.0000e-04
# Epoch 8/100
# 13162/13164 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2532 - mae: 0.3774
# Epoch 8: val_loss improved from 0.24027 to 0.23958, saving model to /content/drive/My Drive/lstm_testing_noaa_gsod_by_station/checkpoints/LSTM_best.keras
#
# Epoch 8: finished saving model to /content/drive/My Drive/lstm_testing_noaa_gsod_by_station/checkpoints/LSTM_best.keras
# 13164/13164 ━━━━━━━━━━━━━━━━━━━━ 127s 10ms/step - loss: 0.2519 - mae: 0.3764 - val_loss: 0.2396 - val_mae: 0.3664 - learning_rate: 1.0000e-04
# Epoch 9/100
# 13161/13164 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2517 - mae: 0.3761
# Epoch 9: val_loss did not improve from 0.23958
# 13164/13164 ━━━━━━━━━━━━━━━━━━━━ 128s 10ms/step - loss: 0.2510 - mae: 0.3755 - val_loss: 0.2405 - val_mae: 0.3667 - learning_rate: 1.0000e-04
# Epoch 10/100
# 13160/13164 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2515 - mae: 0.3760
# Epoch 10: val_loss did not improve from 0.23958
# 13164/13164 ━━━━━━━━━━━━━━━━━━━━ 146s 10ms/step - loss: 0.2506 - mae: 0.3754 - val_loss: 0.2397 - val_mae: 0.3666 - learning_rate: 1.0000e-04
# Epoch 11/100
# 13162/13164 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2507 - mae: 0.3754
# Epoch 11: val_loss improved from 0.23958 to 0.23933, saving model to /content/drive/My Drive/lstm_testing_noaa_gsod_by_station/checkpoints/LSTM_best.keras
#
# Epoch 11: finished saving model to /content/drive/My Drive/lstm_testing_noaa_gsod_by_station/checkpoints/LSTM_best.keras
# 13164/13164 ━━━━━━━━━━━━━━━━━━━━ 130s 10ms/step - loss: 0.2498 - mae: 0.3747 - val_loss: 0.2393 - val_mae: 0.3663 - learning_rate: 1.0000e-04
# Epoch 12/100
# 13158/13164 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2507 - mae: 0.3753
# Epoch 12: val_loss improved from 0.23933 to 0.23887, saving model to /content/drive/My Drive/lstm_testing_noaa_gsod_by_station/checkpoints/LSTM_best.keras
#
# Epoch 12: finished saving model to /content/drive/My Drive/lstm_testing_noaa_gsod_by_station/checkpoints/LSTM_best.keras
# 13164/13164 ━━━━━━━━━━━━━━━━━━━━ 131s 10ms/step - loss: 0.2494 - mae: 0.3743 - val_loss: 0.2389 - val_mae: 0.3661 - learning_rate: 1.0000e-04
# Epoch 13/100
# 13161/13164 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2498 - mae: 0.3746
# Epoch 13: val_loss did not improve from 0.23887
# 13164/13164 ━━━━━━━━━━━━━━━━━━━━ 130s 10ms/step - loss: 0.2491 - mae: 0.3740 - val_loss: 0.2391 - val_mae: 0.3659 - learning_rate: 1.0000e-04
# Epoch 14/100
# 13164/13164 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2497 - mae: 0.3745
# Epoch 14: val_loss improved from 0.23887 to 0.23876, saving model to /content/drive/My Drive/lstm_testing_noaa_gsod_by_station/checkpoints/LSTM_best.keras
#
# Epoch 14: finished saving model to /content/drive/My Drive/lstm_testing_noaa_gsod_by_station/checkpoints/LSTM_best.keras
# 13164/13164 ━━━━━━━━━━━━━━━━━━━━ 140s 10ms/step - loss: 0.2488 - mae: 0.3738 - val_loss: 0.2388 - val_mae: 0.3659 - learning_rate: 1.0000e-04
# Epoch 15/100
# 13158/13164 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2494 - mae: 0.3741
# Epoch 15: val_loss did not improve from 0.23876
# 13164/13164 ━━━━━━━━━━━━━━━━━━━━ 130s 10ms/step - loss: 0.2483 - mae: 0.3733 - val_loss: 0.2390 - val_mae: 0.3658 - learning_rate: 1.0000e-04
# Epoch 16/100
# 13162/13164 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2489 - mae: 0.3737
# Epoch 16: val_loss improved from 0.23876 to 0.23824, saving model to /content/drive/My Drive/lstm_testing_noaa_gsod_by_station/checkpoints/LSTM_best.keras
#
# Epoch 16: finished saving model to /content/drive/My Drive/lstm_testing_noaa_gsod_by_station/checkpoints/LSTM_best.keras
# 13164/13164 ━━━━━━━━━━━━━━━━━━━━ 127s 10ms/step - loss: 0.2479 - mae: 0.3730 - val_loss: 0.2382 - val_mae: 0.3649 - learning_rate: 1.0000e-04
# Epoch 17/100
# 13163/13164 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2483 - mae: 0.3732
# Epoch 17: val_loss did not improve from 0.23824
# 13164/13164 ━━━━━━━━━━━━━━━━━━━━ 126s 10ms/step - loss: 0.2477 - mae: 0.3727 - val_loss: 0.2389 - val_mae: 0.3658 - learning_rate: 1.0000e-04
# Epoch 18/100
# 13161/13164 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2480 - mae: 0.3729
# Epoch 18: val_loss did not improve from 0.23824
# 13164/13164 ━━━━━━━━━━━━━━━━━━━━ 126s 10ms/step - loss: 0.2473 - mae: 0.3723 - val_loss: 0.2385 - val_mae: 0.3653 - learning_rate: 1.0000e-04
# Epoch 19/100
# 13163/13164 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2482 - mae: 0.3732
# Epoch 19: val_loss did not improve from 0.23824
# 13164/13164 ━━━━━━━━━━━━━━━━━━━━ 129s 10ms/step - loss: 0.2473 - mae: 0.3724 - val_loss: 0.2386 - val_mae: 0.3657 - learning_rate: 1.0000e-04
# Epoch 20/100
# 13161/13164 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2475 - mae: 0.3725
# Epoch 20: val_loss did not improve from 0.23824
# 13164/13164 ━━━━━━━━━━━━━━━━━━━━ 129s 10ms/step - loss: 0.2465 - mae: 0.3718 - val_loss: 0.2384 - val_mae: 0.3652 - learning_rate: 1.0000e-04
# Epoch 21/100
# 13162/13164 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2467 - mae: 0.3719
# Epoch 21: val_loss did not improve from 0.23824
# 13164/13164 ━━━━━━━━━━━━━━━━━━━━ 127s 10ms/step - loss: 0.2461 - mae: 0.3715 - val_loss: 0.2388 - val_mae: 0.3655 - learning_rate: 1.0000e-04
# Epoch 22/100
# 13158/13164 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2467 - mae: 0.3719
# Epoch 22: val_loss did not improve from 0.23824
# 13164/13164 ━━━━━━━━━━━━━━━━━━━━ 127s 10ms/step - loss: 0.2459 - mae: 0.3713 - val_loss: 0.2384 - val_mae: 0.3653 - learning_rate: 1.0000e-04
# Epoch 23/100
# 13164/13164 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2468 - mae: 0.3719
# Epoch 23: val_loss did not improve from 0.23824
# 13164/13164 ━━━━━━━━━━━━━━━━━━━━ 144s 11ms/step - loss: 0.2459 - mae: 0.3714 - val_loss: 0.2384 - val_mae: 0.3656 - learning_rate: 1.0000e-04
# Epoch 24/100
# 13162/13164 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2462 - mae: 0.3716
# Epoch 24: val_loss did not improve from 0.23824
# 13164/13164 ━━━━━━━━━━━━━━━━━━━━ 193s 10ms/step - loss: 0.2455 - mae: 0.3711 - val_loss: 0.2384 - val_mae: 0.3654 - learning_rate: 1.0000e-04
# Epoch 25/100
# 13163/13164 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2450 - mae: 0.3708
# Epoch 25: val_loss did not improve from 0.23824
# 13164/13164 ━━━━━━━━━━━━━━━━━━━━ 129s 10ms/step - loss: 0.2446 - mae: 0.3704 - val_loss: 0.2384 - val_mae: 0.3654 - learning_rate: 5.0000e-05
# Epoch 26/100
# 13161/13164 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2458 - mae: 0.3711
# Epoch 26: val_loss did not improve from 0.23824
# 13164/13164 ━━━━━━━━━━━━━━━━━━━━ 132s 10ms/step - loss: 0.2449 - mae: 0.3705 - val_loss: 0.2384 - val_mae: 0.3654 - learning_rate: 5.0000e-05
# Epoch 27/100
# 13161/13164 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2448 - mae: 0.3704
# Epoch 27: val_loss did not improve from 0.23824
# 13164/13164 ━━━━━━━━━━━━━━━━━━━━ 130s 10ms/step - loss: 0.2445 - mae: 0.3703 - val_loss: 0.2392 - val_mae: 0.3660 - learning_rate: 5.0000e-05
# Epoch 28/100
# 13158/13164 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2452 - mae: 0.3707
# Epoch 28: val_loss did not improve from 0.23824
# 13164/13164 ━━━━━━━━━━━━━━━━━━━━ 140s 10ms/step - loss: 0.2444 - mae: 0.3702 - val_loss: 0.2387 - val_mae: 0.3658 - learning_rate: 5.0000e-05
# Epoch 29/100
# 13160/13164 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2446 - mae: 0.3703
# Epoch 29: val_loss did not improve from 0.23824
# 13164/13164 ━━━━━━━━━━━━━━━━━━━━ 136s 10ms/step - loss: 0.2440 - mae: 0.3699 - val_loss: 0.2389 - val_mae: 0.3659 - learning_rate: 5.0000e-05
# Epoch 30/100
# 13161/13164 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2449 - mae: 0.3706
# Epoch 30: val_loss did not improve from 0.23824
# 13164/13164 ━━━━━━━━━━━━━━━━━━━━ 130s 10ms/step - loss: 0.2444 - mae: 0.3703 - val_loss: 0.2385 - val_mae: 0.3656 - learning_rate: 5.0000e-05
# Epoch 31/100
# 13162/13164 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2445 - mae: 0.3702
# Epoch 31: val_loss did not improve from 0.23824
# 13164/13164 ━━━━━━━━━━━━━━━━━━━━ 131s 10ms/step - loss: 0.2441 - mae: 0.3698 - val_loss: 0.2395 - val_mae: 0.3661 - learning_rate: 5.0000e-05
# Epoch 32/100
# 13162/13164 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2449 - mae: 0.3705
# Epoch 32: val_loss did not improve from 0.23824
# 13164/13164 ━━━━━━━━━━━━━━━━━━━━ 132s 10ms/step - loss: 0.2440 - mae: 0.3699 - val_loss: 0.2385 - val_mae: 0.3653 - learning_rate: 5.0000e-05
#
# ===== Stacked_LSTM =====
# Epoch 1/100
# 13162/13164 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.5079 - mae: 0.5396
# Epoch 1: val_loss improved from None to 0.26090, saving model to /content/drive/My Drive/lstm_testing_noaa_gsod_by_station/checkpoints/Stacked_LSTM_best.keras
#
# Epoch 1: finished saving model to /content/drive/My Drive/lstm_testing_noaa_gsod_by_station/checkpoints/Stacked_LSTM_best.keras
# 13164/13164 ━━━━━━━━━━━━━━━━━━━━ 143s 10ms/step - loss: 0.3657 - mae: 0.4588 - val_loss: 0.2609 - val_mae: 0.3876 - learning_rate: 1.0000e-04
# Epoch 2/100
# 13162/13164 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2798 - mae: 0.3999
# Epoch 2: val_loss improved from 0.26090 to 0.24945, saving model to /content/drive/My Drive/lstm_testing_noaa_gsod_by_station/checkpoints/Stacked_LSTM_best.keras
#
# Epoch 2: finished saving model to /content/drive/My Drive/lstm_testing_noaa_gsod_by_station/checkpoints/Stacked_LSTM_best.keras
# 13164/13164 ━━━━━━━━━━━━━━━━━━━━ 135s 10ms/step - loss: 0.2738 - mae: 0.3949 - val_loss: 0.2495 - val_mae: 0.3761 - learning_rate: 1.0000e-04
# Epoch 3/100
# 13162/13164 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2644 - mae: 0.3866
# Epoch 3: val_loss improved from 0.24945 to 0.24567, saving model to /content/drive/My Drive/lstm_testing_noaa_gsod_by_station/checkpoints/Stacked_LSTM_best.keras
#
# Epoch 3: finished saving model to /content/drive/My Drive/lstm_testing_noaa_gsod_by_station/checkpoints/Stacked_LSTM_best.keras
# 13164/13164 ━━━━━━━━━━━━━━━━━━━━ 135s 10ms/step - loss: 0.2617 - mae: 0.3843 - val_loss: 0.2457 - val_mae: 0.3719 - learning_rate: 1.0000e-04
# Epoch 4/100
# 13162/13164 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2572 - mae: 0.3801
# Epoch 4: val_loss improved from 0.24567 to 0.24449, saving model to /content/drive/My Drive/lstm_testing_noaa_gsod_by_station/checkpoints/Stacked_LSTM_best.keras
#
# Epoch 4: finished saving model to /content/drive/My Drive/lstm_testing_noaa_gsod_by_station/checkpoints/Stacked_LSTM_best.keras
# 13164/13164 ━━━━━━━━━━━━━━━━━━━━ 134s 10ms/step - loss: 0.2553 - mae: 0.3785 - val_loss: 0.2445 - val_mae: 0.3710 - learning_rate: 1.0000e-04
# Epoch 5/100
# 13160/13164 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2530 - mae: 0.3764
# Epoch 5: val_loss improved from 0.24449 to 0.24310, saving model to /content/drive/My Drive/lstm_testing_noaa_gsod_by_station/checkpoints/Stacked_LSTM_best.keras
#
# Epoch 5: finished saving model to /content/drive/My Drive/lstm_testing_noaa_gsod_by_station/checkpoints/Stacked_LSTM_best.keras
# 13164/13164 ━━━━━━━━━━━━━━━━━━━━ 135s 10ms/step - loss: 0.2514 - mae: 0.3750 - val_loss: 0.2431 - val_mae: 0.3698 - learning_rate: 1.0000e-04
# Epoch 6/100
# 13161/13164 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2501 - mae: 0.3737
# Epoch 6: val_loss did not improve from 0.24310
# 13164/13164 ━━━━━━━━━━━━━━━━━━━━ 141s 10ms/step - loss: 0.2481 - mae: 0.3722 - val_loss: 0.2457 - val_mae: 0.3727 - learning_rate: 1.0000e-04
# Epoch 7/100
# 13161/13164 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2474 - mae: 0.3713
# Epoch 7: val_loss did not improve from 0.24310
# 13164/13164 ━━━━━━━━━━━━━━━━━━━━ 134s 10ms/step - loss: 0.2461 - mae: 0.3702 - val_loss: 0.2450 - val_mae: 0.3712 - learning_rate: 1.0000e-04
# Epoch 8/100
# 13164/13164 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2453 - mae: 0.3695
# Epoch 8: val_loss did not improve from 0.24310
# 13164/13164 ━━━━━━━━━━━━━━━━━━━━ 134s 10ms/step - loss: 0.2440 - mae: 0.3684 - val_loss: 0.2466 - val_mae: 0.3728 - learning_rate: 1.0000e-04
# Epoch 9/100
# 13161/13164 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2435 - mae: 0.3678
# Epoch 9: val_loss did not improve from 0.24310
# 13164/13164 ━━━━━━━━━━━━━━━━━━━━ 134s 10ms/step - loss: 0.2420 - mae: 0.3666 - val_loss: 0.2479 - val_mae: 0.3738 - learning_rate: 1.0000e-04
# Epoch 10/100
# 13161/13164 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2419 - mae: 0.3663
# Epoch 10: val_loss did not improve from 0.24310
# 13164/13164 ━━━━━━━━━━━━━━━━━━━━ 147s 11ms/step - loss: 0.2409 - mae: 0.3655 - val_loss: 0.2502 - val_mae: 0.3758 - learning_rate: 1.0000e-04
# Epoch 11/100
# 13161/13164 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2410 - mae: 0.3653
# Epoch 11: val_loss did not improve from 0.24310
# 13164/13164 ━━━━━━━━━━━━━━━━━━━━ 138s 10ms/step - loss: 0.2397 - mae: 0.3644 - val_loss: 0.2503 - val_mae: 0.3764 - learning_rate: 1.0000e-04
# Epoch 12/100
# 13164/13164 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2399 - mae: 0.3644
# Epoch 12: val_loss did not improve from 0.24310
# 13164/13164 ━━━━━━━━━━━━━━━━━━━━ 138s 10ms/step - loss: 0.2386 - mae: 0.3633 - val_loss: 0.2534 - val_mae: 0.3797 - learning_rate: 1.0000e-04
# Epoch 13/100
# 13158/13164 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2389 - mae: 0.3637
# Epoch 13: val_loss did not improve from 0.24310
# 13164/13164 ━━━━━━━━━━━━━━━━━━━━ 137s 10ms/step - loss: 0.2375 - mae: 0.3625 - val_loss: 0.2565 - val_mae: 0.3821 - learning_rate: 1.0000e-04
# Epoch 14/100
# 13159/13164 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2374 - mae: 0.3621
# Epoch 14: val_loss did not improve from 0.24310
# 13164/13164 ━━━━━━━━━━━━━━━━━━━━ 142s 10ms/step - loss: 0.2364 - mae: 0.3613 - val_loss: 0.2571 - val_mae: 0.3827 - learning_rate: 5.0000e-05
# Epoch 15/100
# 13158/13164 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2369 - mae: 0.3616
# Epoch 15: val_loss did not improve from 0.24310
# 13164/13164 ━━━━━━━━━━━━━━━━━━━━ 142s 10ms/step - loss: 0.2360 - mae: 0.3610 - val_loss: 0.2569 - val_mae: 0.3822 - learning_rate: 5.0000e-05
# Epoch 16/100
# 13160/13164 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2362 - mae: 0.3611
# Epoch 16: val_loss did not improve from 0.24310
# 13164/13164 ━━━━━━━━━━━━━━━━━━━━ 135s 10ms/step - loss: 0.2355 - mae: 0.3605 - val_loss: 0.2590 - val_mae: 0.3841 - learning_rate: 5.0000e-05
# Epoch 17/100
# 13162/13164 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2361 - mae: 0.3608
# Epoch 17: val_loss did not improve from 0.24310
# 13164/13164 ━━━━━━━━━━━━━━━━━━━━ 136s 10ms/step - loss: 0.2351 - mae: 0.3601 - val_loss: 0.2613 - val_mae: 0.3860 - learning_rate: 5.0000e-05
# Epoch 18/100
# 13159/13164 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2356 - mae: 0.3605
# Epoch 18: val_loss did not improve from 0.24310
# 13164/13164 ━━━━━━━━━━━━━━━━━━━━ 137s 10ms/step - loss: 0.2348 - mae: 0.3598 - val_loss: 0.2622 - val_mae: 0.3869 - learning_rate: 5.0000e-05
# Epoch 19/100
# 13161/13164 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2355 - mae: 0.3603
# Epoch 19: val_loss did not improve from 0.24310
# 13164/13164 ━━━━━━━━━━━━━━━━━━━━ 143s 11ms/step - loss: 0.2346 - mae: 0.3597 - val_loss: 0.2621 - val_mae: 0.3866 - learning_rate: 5.0000e-05
# Epoch 20/100
# 13161/13164 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2348 - mae: 0.3599
# Epoch 20: val_loss did not improve from 0.24310
# 13164/13164 ━━━━━━━━━━━━━━━━━━━━ 139s 11ms/step - loss: 0.2339 - mae: 0.3591 - val_loss: 0.2628 - val_mae: 0.3877 - learning_rate: 5.0000e-05
# Epoch 21/100
# 13161/13164 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2347 - mae: 0.3596
# Epoch 21: val_loss did not improve from 0.24310
# 13164/13164 ━━━━━━━━━━━━━━━━━━━━ 136s 10ms/step - loss: 0.2339 - mae: 0.3590 - val_loss: 0.2641 - val_mae: 0.3882 - learning_rate: 5.0000e-05
#
# ===== GRU =====
# Epoch 1/100
# 13164/13164 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.3842 - mae: 0.4687
# Epoch 1: val_loss improved from None to 0.24774, saving model to /content/drive/My Drive/lstm_testing_noaa_gsod_by_station/checkpoints/GRU_best.keras
#
# Epoch 1: finished saving model to /content/drive/My Drive/lstm_testing_noaa_gsod_by_station/checkpoints/GRU_best.keras
# 13164/13164 ━━━━━━━━━━━━━━━━━━━━ 158s 12ms/step - loss: 0.3111 - mae: 0.4221 - val_loss: 0.2477 - val_mae: 0.3743 - learning_rate: 1.0000e-04
# Epoch 2/100
# 13164/13164 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2684 - mae: 0.3907
# Epoch 2: val_loss improved from 0.24774 to 0.24206, saving model to /content/drive/My Drive/lstm_testing_noaa_gsod_by_station/checkpoints/GRU_best.keras
#
# Epoch 2: finished saving model to /content/drive/My Drive/lstm_testing_noaa_gsod_by_station/checkpoints/GRU_best.keras
# 13164/13164 ━━━━━━━━━━━━━━━━━━━━ 153s 12ms/step - loss: 0.2650 - mae: 0.3879 - val_loss: 0.2421 - val_mae: 0.3690 - learning_rate: 1.0000e-04
# Epoch 3/100
# 13160/13164 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2612 - mae: 0.3843
# Epoch 3: val_loss improved from 0.24206 to 0.24036, saving model to /content/drive/My Drive/lstm_testing_noaa_gsod_by_station/checkpoints/GRU_best.keras
#
# Epoch 3: finished saving model to /content/drive/My Drive/lstm_testing_noaa_gsod_by_station/checkpoints/GRU_best.keras
# 13164/13164 ━━━━━━━━━━━━━━━━━━━━ 152s 12ms/step - loss: 0.2596 - mae: 0.3830 - val_loss: 0.2404 - val_mae: 0.3670 - learning_rate: 1.0000e-04
# Epoch 4/100
# 13164/13164 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2580 - mae: 0.3814
# Epoch 4: val_loss improved from 0.24036 to 0.23907, saving model to /content/drive/My Drive/lstm_testing_noaa_gsod_by_station/checkpoints/GRU_best.keras
#
# Epoch 4: finished saving model to /content/drive/My Drive/lstm_testing_noaa_gsod_by_station/checkpoints/GRU_best.keras
# 13164/13164 ━━━━━━━━━━━━━━━━━━━━ 154s 12ms/step - loss: 0.2567 - mae: 0.3805 - val_loss: 0.2391 - val_mae: 0.3662 - learning_rate: 1.0000e-04
# Epoch 5/100
# 13161/13164 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2571 - mae: 0.3807
# Epoch 5: val_loss improved from 0.23907 to 0.23856, saving model to /content/drive/My Drive/lstm_testing_noaa_gsod_by_station/checkpoints/GRU_best.keras
#
# Epoch 5: finished saving model to /content/drive/My Drive/lstm_testing_noaa_gsod_by_station/checkpoints/GRU_best.keras
# 13164/13164 ━━━━━━━━━━━━━━━━━━━━ 201s 12ms/step - loss: 0.2558 - mae: 0.3796 - val_loss: 0.2386 - val_mae: 0.3655 - learning_rate: 1.0000e-04
# Epoch 6/100
# 13161/13164 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2553 - mae: 0.3791
# Epoch 6: val_loss improved from 0.23856 to 0.23768, saving model to /content/drive/My Drive/lstm_testing_noaa_gsod_by_station/checkpoints/GRU_best.keras
#
# Epoch 6: finished saving model to /content/drive/My Drive/lstm_testing_noaa_gsod_by_station/checkpoints/GRU_best.keras
# 13164/13164 ━━━━━━━━━━━━━━━━━━━━ 152s 12ms/step - loss: 0.2542 - mae: 0.3783 - val_loss: 0.2377 - val_mae: 0.3644 - learning_rate: 1.0000e-04
# Epoch 7/100
# 13161/13164 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2549 - mae: 0.3786
# Epoch 7: val_loss improved from 0.23768 to 0.23742, saving model to /content/drive/My Drive/lstm_testing_noaa_gsod_by_station/checkpoints/GRU_best.keras
#
# Epoch 7: finished saving model to /content/drive/My Drive/lstm_testing_noaa_gsod_by_station/checkpoints/GRU_best.keras
# 13164/13164 ━━━━━━━━━━━━━━━━━━━━ 204s 12ms/step - loss: 0.2534 - mae: 0.3775 - val_loss: 0.2374 - val_mae: 0.3644 - learning_rate: 1.0000e-04
# Epoch 8/100
# 13164/13164 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2533 - mae: 0.3773
# Epoch 8: val_loss improved from 0.23742 to 0.23664, saving model to /content/drive/My Drive/lstm_testing_noaa_gsod_by_station/checkpoints/GRU_best.keras
#
# Epoch 8: finished saving model to /content/drive/My Drive/lstm_testing_noaa_gsod_by_station/checkpoints/GRU_best.keras
# 13164/13164 ━━━━━━━━━━━━━━━━━━━━ 204s 12ms/step - loss: 0.2525 - mae: 0.3766 - val_loss: 0.2366 - val_mae: 0.3637 - learning_rate: 1.0000e-04
# Epoch 9/100
# 13164/13164 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2529 - mae: 0.3771
# Epoch 9: val_loss improved from 0.23664 to 0.23661, saving model to /content/drive/My Drive/lstm_testing_noaa_gsod_by_station/checkpoints/GRU_best.keras
#
# Epoch 9: finished saving model to /content/drive/My Drive/lstm_testing_noaa_gsod_by_station/checkpoints/GRU_best.keras
# 13164/13164 ━━━━━━━━━━━━━━━━━━━━ 155s 12ms/step - loss: 0.2518 - mae: 0.3762 - val_loss: 0.2366 - val_mae: 0.3638 - learning_rate: 1.0000e-04
# Epoch 10/100
# 13161/13164 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2526 - mae: 0.3768
# Epoch 10: val_loss improved from 0.23661 to 0.23632, saving model to /content/drive/My Drive/lstm_testing_noaa_gsod_by_station/checkpoints/GRU_best.keras
#
# Epoch 10: finished saving model to /content/drive/My Drive/lstm_testing_noaa_gsod_by_station/checkpoints/GRU_best.keras
# 13164/13164 ━━━━━━━━━━━━━━━━━━━━ 159s 12ms/step - loss: 0.2515 - mae: 0.3760 - val_loss: 0.2363 - val_mae: 0.3633 - learning_rate: 1.0000e-04
# Epoch 11/100
# 13162/13164 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2516 - mae: 0.3760
# Epoch 11: val_loss improved from 0.23632 to 0.23569, saving model to /content/drive/My Drive/lstm_testing_noaa_gsod_by_station/checkpoints/GRU_best.keras
#
# Epoch 11: finished saving model to /content/drive/My Drive/lstm_testing_noaa_gsod_by_station/checkpoints/GRU_best.keras
# 13164/13164 ━━━━━━━━━━━━━━━━━━━━ 200s 12ms/step - loss: 0.2509 - mae: 0.3755 - val_loss: 0.2357 - val_mae: 0.3627 - learning_rate: 1.0000e-04
# Epoch 12/100
# 13163/13164 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2516 - mae: 0.3759
# Epoch 12: val_loss improved from 0.23569 to 0.23559, saving model to /content/drive/My Drive/lstm_testing_noaa_gsod_by_station/checkpoints/GRU_best.keras
#
# Epoch 12: finished saving model to /content/drive/My Drive/lstm_testing_noaa_gsod_by_station/checkpoints/GRU_best.keras
# 13164/13164 ━━━━━━━━━━━━━━━━━━━━ 200s 12ms/step - loss: 0.2503 - mae: 0.3750 - val_loss: 0.2356 - val_mae: 0.3629 - learning_rate: 1.0000e-04
# Epoch 13/100
# 13159/13164 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2510 - mae: 0.3754
# Epoch 13: val_loss improved from 0.23559 to 0.23527, saving model to /content/drive/My Drive/lstm_testing_noaa_gsod_by_station/checkpoints/GRU_best.keras
#
# Epoch 13: finished saving model to /content/drive/My Drive/lstm_testing_noaa_gsod_by_station/checkpoints/GRU_best.keras
# 13164/13164 ━━━━━━━━━━━━━━━━━━━━ 200s 12ms/step - loss: 0.2499 - mae: 0.3746 - val_loss: 0.2353 - val_mae: 0.3627 - learning_rate: 1.0000e-04
# Epoch 14/100
# 13163/13164 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2506 - mae: 0.3753
# Epoch 14: val_loss improved from 0.23527 to 0.23516, saving model to /content/drive/My Drive/lstm_testing_noaa_gsod_by_station/checkpoints/GRU_best.keras
#
# Epoch 14: finished saving model to /content/drive/My Drive/lstm_testing_noaa_gsod_by_station/checkpoints/GRU_best.keras
# 13164/13164 ━━━━━━━━━━━━━━━━━━━━ 153s 12ms/step - loss: 0.2494 - mae: 0.3743 - val_loss: 0.2352 - val_mae: 0.3622 - learning_rate: 1.0000e-04
# Epoch 15/100
# 13163/13164 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2501 - mae: 0.3745
# Epoch 15: val_loss did not improve from 0.23516
# 13164/13164 ━━━━━━━━━━━━━━━━━━━━ 158s 12ms/step - loss: 0.2491 - mae: 0.3739 - val_loss: 0.2353 - val_mae: 0.3622 - learning_rate: 1.0000e-04
# Epoch 16/100
# 13160/13164 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2493 - mae: 0.3740
# Epoch 16: val_loss improved from 0.23516 to 0.23500, saving model to /content/drive/My Drive/lstm_testing_noaa_gsod_by_station/checkpoints/GRU_best.keras
#
# Epoch 16: finished saving model to /content/drive/My Drive/lstm_testing_noaa_gsod_by_station/checkpoints/GRU_best.keras
# 13164/13164 ━━━━━━━━━━━━━━━━━━━━ 198s 12ms/step - loss: 0.2486 - mae: 0.3735 - val_loss: 0.2350 - val_mae: 0.3623 - learning_rate: 1.0000e-04
# Epoch 17/100
# 13160/13164 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2491 - mae: 0.3738
# Epoch 17: val_loss improved from 0.23500 to 0.23485, saving model to /content/drive/My Drive/lstm_testing_noaa_gsod_by_station/checkpoints/GRU_best.keras
#
# Epoch 17: finished saving model to /content/drive/My Drive/lstm_testing_noaa_gsod_by_station/checkpoints/GRU_best.keras
# 13164/13164 ━━━━━━━━━━━━━━━━━━━━ 155s 12ms/step - loss: 0.2483 - mae: 0.3733 - val_loss: 0.2349 - val_mae: 0.3624 - learning_rate: 1.0000e-04
# Epoch 18/100
# 13163/13164 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2491 - mae: 0.3740
# Epoch 18: val_loss improved from 0.23485 to 0.23470, saving model to /content/drive/My Drive/lstm_testing_noaa_gsod_by_station/checkpoints/GRU_best.keras
#
# Epoch 18: finished saving model to /content/drive/My Drive/lstm_testing_noaa_gsod_by_station/checkpoints/GRU_best.keras
# 13164/13164 ━━━━━━━━━━━━━━━━━━━━ 159s 12ms/step - loss: 0.2483 - mae: 0.3734 - val_loss: 0.2347 - val_mae: 0.3622 - learning_rate: 1.0000e-04
# Epoch 19/100
# 13163/13164 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2493 - mae: 0.3742
# Epoch 19: val_loss improved from 0.23470 to 0.23441, saving model to /content/drive/My Drive/lstm_testing_noaa_gsod_by_station/checkpoints/GRU_best.keras
#
# Epoch 19: finished saving model to /content/drive/My Drive/lstm_testing_noaa_gsod_by_station/checkpoints/GRU_best.keras
# 13164/13164 ━━━━━━━━━━━━━━━━━━━━ 202s 12ms/step - loss: 0.2481 - mae: 0.3732 - val_loss: 0.2344 - val_mae: 0.3616 - learning_rate: 1.0000e-04
# Epoch 20/100
# 13163/13164 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2484 - mae: 0.3733
# Epoch 20: val_loss did not improve from 0.23441
# 13164/13164 ━━━━━━━━━━━━━━━━━━━━ 158s 12ms/step - loss: 0.2477 - mae: 0.3728 - val_loss: 0.2345 - val_mae: 0.3619 - learning_rate: 1.0000e-04
# Epoch 21/100
# 13161/13164 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2483 - mae: 0.3732
# Epoch 21: val_loss improved from 0.23441 to 0.23427, saving model to /content/drive/My Drive/lstm_testing_noaa_gsod_by_station/checkpoints/GRU_best.keras
#
# Epoch 21: finished saving model to /content/drive/My Drive/lstm_testing_noaa_gsod_by_station/checkpoints/GRU_best.keras
# 13164/13164 ━━━━━━━━━━━━━━━━━━━━ 160s 12ms/step - loss: 0.2475 - mae: 0.3727 - val_loss: 0.2343 - val_mae: 0.3616 - learning_rate: 1.0000e-04
# Epoch 22/100
# 13161/13164 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2476 - mae: 0.3728
# Epoch 22: val_loss did not improve from 0.23427
# 13164/13164 ━━━━━━━━━━━━━━━━━━━━ 157s 12ms/step - loss: 0.2469 - mae: 0.3722 - val_loss: 0.2347 - val_mae: 0.3621 - learning_rate: 1.0000e-04
# Epoch 23/100
# 13162/13164 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2475 - mae: 0.3728
# Epoch 23: val_loss did not improve from 0.23427
# 13164/13164 ━━━━━━━━━━━━━━━━━━━━ 204s 12ms/step - loss: 0.2468 - mae: 0.3722 - val_loss: 0.2346 - val_mae: 0.3621 - learning_rate: 1.0000e-04
# Epoch 24/100
# 13161/13164 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2471 - mae: 0.3723
# Epoch 24: val_loss did not improve from 0.23427
# 13164/13164 ━━━━━━━━━━━━━━━━━━━━ 157s 12ms/step - loss: 0.2464 - mae: 0.3718 - val_loss: 0.2344 - val_mae: 0.3619 - learning_rate: 1.0000e-04
# Epoch 25/100
# 13160/13164 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2472 - mae: 0.3724
# Epoch 25: val_loss did not improve from 0.23427
# 13164/13164 ━━━━━━━━━━━━━━━━━━━━ 157s 12ms/step - loss: 0.2464 - mae: 0.3719 - val_loss: 0.2345 - val_mae: 0.3623 - learning_rate: 1.0000e-04
# Epoch 26/100
# 13163/13164 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2472 - mae: 0.3723
# Epoch 26: val_loss improved from 0.23427 to 0.23399, saving model to /content/drive/My Drive/lstm_testing_noaa_gsod_by_station/checkpoints/GRU_best.keras
#
# Epoch 26: finished saving model to /content/drive/My Drive/lstm_testing_noaa_gsod_by_station/checkpoints/GRU_best.keras
# 13164/13164 ━━━━━━━━━━━━━━━━━━━━ 159s 12ms/step - loss: 0.2463 - mae: 0.3716 - val_loss: 0.2340 - val_mae: 0.3618 - learning_rate: 1.0000e-04
# Epoch 27/100
# 13161/13164 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2468 - mae: 0.3720
# Epoch 27: val_loss did not improve from 0.23399
# 13164/13164 ━━━━━━━━━━━━━━━━━━━━ 157s 12ms/step - loss: 0.2459 - mae: 0.3714 - val_loss: 0.2341 - val_mae: 0.3621 - learning_rate: 1.0000e-04
# Epoch 28/100
# 13161/13164 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2465 - mae: 0.3719
# Epoch 28: val_loss did not improve from 0.23399
# 13164/13164 ━━━━━━━━━━━━━━━━━━━━ 156s 12ms/step - loss: 0.2456 - mae: 0.3713 - val_loss: 0.2341 - val_mae: 0.3618 - learning_rate: 1.0000e-04
# Epoch 29/100
# 13162/13164 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2461 - mae: 0.3715
# Epoch 29: val_loss did not improve from 0.23399
# 13164/13164 ━━━━━━━━━━━━━━━━━━━━ 158s 12ms/step - loss: 0.2457 - mae: 0.3713 - val_loss: 0.2342 - val_mae: 0.3621 - learning_rate: 1.0000e-04
# Epoch 30/100
# 13162/13164 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2462 - mae: 0.3717
# Epoch 30: val_loss did not improve from 0.23399
# 13164/13164 ━━━━━━━━━━━━━━━━━━━━ 161s 12ms/step - loss: 0.2454 - mae: 0.3712 - val_loss: 0.2350 - val_mae: 0.3631 - learning_rate: 1.0000e-04
# Epoch 31/100
# 13164/13164 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2456 - mae: 0.3713
# Epoch 31: val_loss did not improve from 0.23399
# 13164/13164 ━━━━━━━━━━━━━━━━━━━━ 205s 12ms/step - loss: 0.2449 - mae: 0.3707 - val_loss: 0.2342 - val_mae: 0.3620 - learning_rate: 1.0000e-04
# Epoch 32/100
# 13163/13164 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2455 - mae: 0.3711
# Epoch 32: val_loss did not improve from 0.23399
# 13164/13164 ━━━━━━━━━━━━━━━━━━━━ 197s 12ms/step - loss: 0.2449 - mae: 0.3706 - val_loss: 0.2343 - val_mae: 0.3620 - learning_rate: 1.0000e-04
# Epoch 33/100
# 13163/13164 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2459 - mae: 0.3715
# Epoch 33: val_loss did not improve from 0.23399
# 13164/13164 ━━━━━━━━━━━━━━━━━━━━ 159s 12ms/step - loss: 0.2448 - mae: 0.3707 - val_loss: 0.2349 - val_mae: 0.3628 - learning_rate: 1.0000e-04
# Epoch 34/100
# 13163/13164 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2456 - mae: 0.3713
# Epoch 34: val_loss did not improve from 0.23399
# 13164/13164 ━━━━━━━━━━━━━━━━━━━━ 202s 12ms/step - loss: 0.2448 - mae: 0.3706 - val_loss: 0.2345 - val_mae: 0.3626 - learning_rate: 1.0000e-04
# Epoch 35/100
# 13162/13164 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2445 - mae: 0.3703
# Epoch 35: val_loss did not improve from 0.23399
# 13164/13164 ━━━━━━━━━━━━━━━━━━━━ 162s 12ms/step - loss: 0.2437 - mae: 0.3697 - val_loss: 0.2347 - val_mae: 0.3626 - learning_rate: 5.0000e-05
# Epoch 36/100
# 13164/13164 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2450 - mae: 0.3706
# Epoch 36: val_loss did not improve from 0.23399
# 13164/13164 ━━━━━━━━━━━━━━━━━━━━ 160s 12ms/step - loss: 0.2441 - mae: 0.3700 - val_loss: 0.2345 - val_mae: 0.3623 - learning_rate: 5.0000e-05
# Epoch 37/100
# 13162/13164 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2442 - mae: 0.3703
# Epoch 37: val_loss did not improve from 0.23399
# 13164/13164 ━━━━━━━━━━━━━━━━━━━━ 205s 12ms/step - loss: 0.2438 - mae: 0.3698 - val_loss: 0.2347 - val_mae: 0.3625 - learning_rate: 5.0000e-05
# Epoch 38/100
# 13162/13164 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2447 - mae: 0.3704
# Epoch 38: val_loss did not improve from 0.23399
# 13164/13164 ━━━━━━━━━━━━━━━━━━━━ 160s 12ms/step - loss: 0.2439 - mae: 0.3698 - val_loss: 0.2340 - val_mae: 0.3618 - learning_rate: 5.0000e-05
# Epoch 39/100
# 13160/13164 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2446 - mae: 0.3704
# Epoch 39: val_loss did not improve from 0.23399
# 13164/13164 ━━━━━━━━━━━━━━━━━━━━ 202s 12ms/step - loss: 0.2438 - mae: 0.3699 - val_loss: 0.2344 - val_mae: 0.3622 - learning_rate: 5.0000e-05
# Epoch 40/100
# 13161/13164 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2442 - mae: 0.3701
# Epoch 40: val_loss did not improve from 0.23399
# 13164/13164 ━━━━━━━━━━━━━━━━━━━━ 159s 12ms/step - loss: 0.2437 - mae: 0.3699 - val_loss: 0.2343 - val_mae: 0.3622 - learning_rate: 5.0000e-05
# Epoch 41/100
# 13160/13164 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2445 - mae: 0.3702
# Epoch 41: val_loss did not improve from 0.23399
# 13164/13164 ━━━━━━━━━━━━━━━━━━━━ 160s 12ms/step - loss: 0.2437 - mae: 0.3697 - val_loss: 0.2342 - val_mae: 0.3619 - learning_rate: 5.0000e-05
# Epoch 42/100
# 13160/13164 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2441 - mae: 0.3701
# Epoch 42: val_loss did not improve from 0.23399
# 13164/13164 ━━━━━━━━━━━━━━━━━━━━ 163s 12ms/step - loss: 0.2438 - mae: 0.3699 - val_loss: 0.2345 - val_mae: 0.3621 - learning_rate: 5.0000e-05
#
# Meilleur modèle (RMSE moyen test): GRU

# %%
import math
import numpy as np
import matplotlib.pyplot as plt

# Calcul du facteur d'échelle moyen pour revenir en °C (approximation pour la courbe globale)
tgt_indices = [FEATURES.index(t) for t in TARGETS]
# Avec StandardScaler, scale_ représente l'écart-type. On l'utilise comme facteur visuel.
scale_factor = np.mean(scaler_X.scale_[tgt_indices])

n_models = len(MODEL_NAMES)
# 3 colonnes: MSE (norm), RMSE (°C), MAE (°C)
fig, axes = plt.subplots(n_models, 3, figsize=(18, 4 * n_models))

# Au cas où un seul modèle est listé, on s'assure que 'axes' est un tableau 2D
if n_models == 1:
    axes = np.expand_dims(axes, axis=0)

for i, name in enumerate(MODEL_NAMES):
    if name in histories and "loss" in histories[name]:
        h = histories[name]
        epochs_range = range(1, len(h["loss"]) + 1)

        # --- 1. MSE (Norm) ---
        ax = axes[i, 0]
        ax.plot(epochs_range, h["loss"], label="Train MSE", color="blue")
        if "val_loss" in h:
            ax.plot(epochs_range, h["val_loss"], label="Val MSE", color="orange")
        ax.set_title(f"{name} - MSE (Norm)")
        ax.set_xlabel("Epochs")
        ax.set_ylabel("MSE")
        ax.legend()
        ax.grid(alpha=0.3)

        # --- 2. Real RMSE (°C) ---
        ax = axes[i, 1]
        train_rmse = np.sqrt(h["loss"]) * scale_factor
        ax.plot(epochs_range, train_rmse, label="Train RMSE", color="blue")
        if "val_loss" in h:
            val_rmse = np.sqrt(h["val_loss"]) * scale_factor
            ax.plot(epochs_range, val_rmse, label="Val RMSE", color="orange")
        ax.set_title(f"{name} - RMSE (Physique estimé)")
        ax.set_xlabel("Epochs")
        ax.set_ylabel("RMSE (°C)")
        ax.legend()
        ax.grid(alpha=0.3)

        # --- 3. Real MAE (°C) ---
        ax = axes[i, 2]
        if "mae" in h:
            train_mae = np.array(h["mae"]) * scale_factor
            ax.plot(epochs_range, train_mae, label="Train MAE", color="blue")
            if "val_mae" in h:
                val_mae = np.array(h["val_mae"]) * scale_factor
                ax.plot(epochs_range, val_mae, label="Val MAE", color="orange")
            ax.set_title(f"{name} - MAE (Physique estimé)")
            ax.set_xlabel("Epochs")
            ax.set_ylabel("MAE (°C)")
            ax.legend()
            ax.grid(alpha=0.3)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 7bis. Comparaison des modèles
# Tableau récapitulatif (RMSE / MAE / R² par cible, en unités physiques sur le jeu
# de test) et comparaison visuelle du RMSE.

# %%
# ── Tableau comparatif ──
rows = []
for name in MODEL_NAMES:
    r = results[name]
    row = {"modèle": name, "params(M)": round(r["n_params"] / 1e6, 3)}
    for j, t in enumerate(TARGETS):
        row[f"RMSE_{t}"] = round(float(r["rmse"][:, j].mean()), 3)
        row[f"MAE_{t}"]  = round(float(r["mae"][:, j].mean()), 3)
        row[f"R2_{t}"]   = round(float(r["r2"][j]), 3)
    rows.append(row)
bench_df = pd.DataFrame(rows).set_index("modèle")
print(bench_df.to_string())
bench_df
# Out:
#               params(M)  RMSE_heat_index  MAE_heat_index  R2_heat_index  RMSE_wind_chill  MAE_wind_chill  R2_wind_chill
# modèle
# LSTM              0.014            3.608           2.731          0.703            3.055           2.407          0.781
# Stacked_LSTM      0.016            3.613           2.712          0.704            3.077           2.438          0.779
# GRU               0.011            3.500           2.635          0.721            2.968           2.339          0.793
#               params(M)  RMSE_heat_index  MAE_heat_index  R2_heat_index  \
# modèle
# LSTM              0.014            3.608           2.731          0.703
# Stacked_LSTM      0.016            3.613           2.712          0.704
# GRU               0.011            3.500           2.635          0.721
#
#               RMSE_wind_chill  MAE_wind_chill  R2_wind_chill
# modèle
# LSTM                    3.055           2.407          0.781
# Stacked_LSTM            3.077           2.438          0.779
# GRU                     2.968           2.339          0.793

# %%
# ── Comparaison visuelle : RMSE, MAE & R² par modèle & cible ──
x = np.arange(len(MODEL_NAMES)); w = 0.8 / len(TARGETS)
metrics = [("RMSE", "rmse", "RMSE (°C)"), ("MAE", "mae", "MAE (°C)"), ("R²", "r2", "R²")]

fig, axes = plt.subplots(1, 3, figsize=(18, 5))
for i, (label, key, ylabel) in enumerate(metrics):
    ax = axes[i]
    for k, t in enumerate(TARGETS):
        # RMSE and MAE are computed per horizon, so we take the mean.
        # R2 is a single value per target.
        if key in ["rmse", "mae"]:
            vals = [results[n][key][:, k].mean() for n in MODEL_NAMES]
        else:
            vals = [results[n][key][k] for n in MODEL_NAMES]
        bars = ax.bar(x + (k - (len(TARGETS) - 1) / 2) * w, vals, w, label=t)
        ax.bar_label(bars, fmt='%.3f', padding=3)
    ax.set_xticks(x); ax.set_xticklabels(MODEL_NAMES)
    ax.set_ylabel(ylabel); ax.set_title(f"Comparaison : {label}")
    ax.legend()
plt.tight_layout(); plt.show()

# %% [markdown]
# ## 7ter. Métriques par horizon de prévision
# RMSE et MAE en fonction de l'horizon `J+1 … J+OUTPUT_WINDOW` (le barchart ci-dessus
# ne montre que la moyenne sur les horizons). L'erreur croît normalement avec
# l'horizon : prévoir J+7 est plus dur que J+1.

# %%
# ── RMSE & MAE par horizon (J+1 ... J+H), une courbe par modèle ──
H = OUTPUT_WINDOW
horizons = np.arange(1, H + 1)
panels = [("RMSE", "rmse"), ("MAE", "mae")] # Removed R2 since it's not computed per horizon
fig, axes = plt.subplots(len(panels), len(TARGETS),
                         figsize=(6 * len(TARGETS), 4 * len(panels)), squeeze=False)
for r, (label, key) in enumerate(panels):
    for j, t in enumerate(TARGETS):
        ax = axes[r, j]
        for name in MODEL_NAMES:
            ax.plot(horizons, results[name][key][:, j], marker="o", label=name)
        ax.set_title(f"{label} par horizon — {t}")
        ax.set_xlabel("horizon (jours, J+h)"); ax.set_ylabel(f"{label} (°C)")
        ax.set_xticks(horizons); ax.grid(alpha=.3); ax.legend()
plt.tight_layout(); plt.show()

# %% [markdown]
# ## 8. Prédictions vs réel (meilleur modèle)

# %%
# ── 1. Prévisions J+1 vs réel pour le meilleur modèle (début du jeu de test) ──
plt.figure(figsize=(12, 5))
for j, t in enumerate(TARGETS):
    plt.subplot(1, 2, j + 1)
    n = min(300, pred.shape[0])
    plt.plot(true[:n, 0, j], label="réel", lw=1)
    plt.plot(pred[:n, 0, j], label="prévu (J+1)", lw=1, alpha=0.8)
    plt.title(f"{t} — J+1 ({best_name}, test)"); plt.legend()
    plt.xlabel("échantillon"); plt.ylabel("°C")
plt.tight_layout(); plt.show()


# ── 2. Analyse géographique par station (Où le modèle échoue/réussit ?) ──
print("\n=== Calcul du RMSE par station ===")
station_metrics = []
for st, g in test_n.groupby("station_name"):
    X_st, y_st = make_sequences(g)
    if len(X_st) == 0: continue
    pred_st = model.predict(X_st, verbose=0)
    true_st_phys = inv_y(y_st)
    pred_st_phys = inv_y(pred_st)
    rmse_st, _, _ = eval_metrics(pred_st_phys, true_st_phys)
    station_metrics.append({
        "station": st,
        "RMSE_HeatIndex": rmse_st[:, 0].mean(),
        "RMSE_WindChill": rmse_st[:, 1].mean()
    })

st_df = pd.DataFrame(station_metrics).sort_values("RMSE_HeatIndex", ascending=False)
plt.figure(figsize=(12, 8))
sns.barplot(data=st_df, x="RMSE_HeatIndex", y="station", palette="flare")
plt.title(f"RMSE HeatIndex moyen par station ({best_name} sur Test)")
plt.xlabel("RMSE (°C)")
plt.grid(axis='x', alpha=0.3)
plt.tight_layout(); plt.show()
# Out:
# === Calcul du RMSE par station ===

# %% [markdown]
# ## 9. Save artifacts

# %%
# NB : tous les modèles ont déjà été sauvegardés dans ART_DIR/models/ pendant le benchmark,
# et les checkpoints de reprise sont dans ART_DIR/checkpoints/.
best = results[best_name]["model"]
best.save(str(ART_DIR / "lstm_nasa_power.keras"))          # alias pratique du MEILLEUR modèle
joblib.dump(scaler_X, ART_DIR / "scaler_X.pkl")            # scalers Standard (fit train)
# Plus de scaler_y !
bench_df.to_csv(ART_DIR / "benchmark_metrics.csv")         # tableau comparatif

meta = {
    "framework": "tensorflow", "best_model": best_name,
    "models": {name: {"path": f"models/{name}.keras",
                      "rmse_mean": round(float(results[name]["rmse"].mean()), 3),
                      "params": int(results[name]["n_params"])}
               for name in MODEL_NAMES},
    "features": FEATURES, "targets": TARGETS,
    "scaler": "standard", "feature_range": ["mean", "std"],
    "split": {"train": TRAIN_RATIO, "val": VAL_RATIO, "test": TEST_RATIO,
              "scheme": "per-station chronological"},
    "input_window": INPUT_WINDOW, "output_window": OUTPUT_WINDOW,
    "hidden": HIDDEN, "n_layers": N_LAYERS,
}
json.dump(meta, open(ART_DIR / "lstm_meta.json", "w"), indent=2)
print("Tous les modèles sauvegardés ->", MODELS_DIR, "(", ", ".join(MODEL_NAMES), ")")
print("meilleur alias:", ART_DIR / "lstm_nasa_power.keras",
      "| scalers | benchmark_metrics.csv | lstm_meta.json")
# Out:
# Tous les modèles sauvegardés -> /content/drive/My Drive/lstm_testing_noaa_gsod_by_station/models ( LSTM, Stacked_LSTM, GRU )
# meilleur alias: /content/drive/My Drive/lstm_testing_noaa_gsod_by_station/lstm_nasa_power.keras | scalers | benchmark_metrics.csv | lstm_meta.json
